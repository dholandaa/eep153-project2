# %%
"""
1) Gain authorization with Google API for sheet
2) Import Sheet(s) as Pandas Dataframe(s)
3) Convert Sheet(s) to CSVs in proper format (note on Monday)
"""
#!pip install -r requirements.txt
#!pip install gspread
#!pip install oauth2client
# Out:
# Requirement already satisfied: Pint>=0.8.1 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (0.11)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.16.5)
# Requirement already satisfied: pandas>=0.23.3 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (0.25.1)
# Requirement already satisfied: requests>=2.20.0 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 15)) (2.22.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: gspread>=3.2.0 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: oauth2client>=4.1.3 in c:\users\laial\anaconda3\lib\site-packages (from -r requirements.txt (line 22)) (4.1.3)
# Requirement already satisfied: setuptools in c:\users\laial\anaconda3\lib\site-packages (from Pint>=0.8.1->-r requirements.txt (line 2)) (41.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\laial\anaconda3\lib\site-packages (from pandas>=0.23.3->-r requirements.txt (line 11)) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\laial\anaconda3\lib\site-packages (from pandas>=0.23.3->-r requirements.txt (line 11)) (2019.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\laial\anaconda3\lib\site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\laial\anaconda3\lib\site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\laial\anaconda3\lib\site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laial\anaconda3\lib\site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (2019.9.11)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 22)) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 22)) (4.0)
# Requirement already satisfied: six>=1.6.1 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 22)) (1.12.0)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 22)) (0.17.0)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 22)) (0.4.8)
# Requirement already satisfied: oauth2client in c:\users\laial\anaconda3\lib\site-packages (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client) (4.0)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client) (0.17.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: six>=1.6.1 in c:\users\laial\anaconda3\lib\site-packages (from oauth2client) (1.12.0)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import fooddatacentral as fdc

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
json_file = 'eep153-project2-269718.json'
spreadsheet = "16eMvk2KBVOd30v7wTqp1ZGoFno9f9FmfxRBE_jcrLcI"
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file, scope)
gc = gspread.authorize(credentials)
sh = gc.open_by_key(spreadsheet)

# %%
sh.worksheets()
# Out:
# [<Worksheet 'Calories' id:0>,
#  <Worksheet 'Food Data' id:1188532609>,
#  <Worksheet 'CND<>US Conversion' id:1594732978>,
#  <Worksheet 'Nutrition_Min' id:1079378864>,
#  <Worksheet 'Nutrition_Max' id:3223398>]

# %%
wks_calories = sh.worksheet("Calories")
wks_food_data = sh.worksheet("Food Data")
wks_nutrition_min = sh.worksheet("Nutrition_Min")
wks_nutrition_max = sh.worksheet("Nutrition_Max")

# %%
#headers = data.pop(0)
#data_df = pd.DataFrame(data,columns=headers)
# Calories Data
data_calories = wks_calories.get_all_values()
headers = data_calories.pop(0)
df_calories = pd.DataFrame(data_calories,columns=headers)

# Food Data
data_food_data = wks_food_data.get_all_values()
headers = data_food_data.pop(0)
df_food_data = pd.DataFrame(data_food_data,columns=headers)

# Nutrition Data Min
data_nutrition_min = wks_nutrition_min.get_all_values()
headers = data_nutrition_min.pop(0)
df_nutrition_min = pd.DataFrame(data_nutrition_min,columns=headers)

# Nutrition Data Max
data_nutrition_max = wks_nutrition_max.get_all_values()
headers = data_nutrition_max.pop(0)
df_nutrition_max = pd.DataFrame(data_nutrition_max,columns=headers)

# %%
#df_calories.head()

# %%
df_food_data.head()
# Out:
#            Food Quantity  Units Price  Date Location FDC  \
# 0  Fruit Basket        1  $/lbs  0.88  1997      USA
# 1  Fruit Basket        1  $/lbs  0.92  1998      USA
# 2  Fruit Basket        1  $/lbs  1.02  1999      USA
# 3  Fruit Basket        1  $/lbs  0.97  2000      USA
# 4  Fruit Basket        1  $/lbs     1  2001      USA
#
#   Price; Pounds to 100G               Link:
# 0            0.19400656
# 1
# 2
# 3
# 4

# %%
df_nutrition_min.head()
# Out:
#             Nutrition            Source\nof goal Child 1-3 Female 4-8  \
# 0  Source: Appendix 7  Calorie level(s) assessed     1,000      1,200
# 1      Macronutrients
# 2           Protein g                        RDA        13         19
# 3      Protein % kcal                       AMDR         5         10
# 4      Carbohydrate g                        RDA       130        130
#
#      Male 4-8 Female 9-13 Male 9-13 Female 14-18        Male 14-18  \
# 0  1400\n1600       1,600     1,800        1,800  2200\n2800\n3200
# 1
# 2          19          34        34           46                52
# 3          10          10        10           10                10
# 4         130         130       130          130               130
#
#   Female 19-30        Male 19-30 Female 31-50 Male 31-50 Female 51+ Male 51+
# 0        2,000  2400\n2600\n3000        1,800      2,200      1,600    2,000
# 1
# 2           46                56           46         56         46       56
# 3           10                10           10         10         10       10
# 4          130               130          130        130        130      130

# %%
df_nutrition_max.head()
# Out:
#             Nutrition            Source\nof goal Child 1-3 Female 4-8  \
# 0  Source: Appendix 7  Calorie level(s) assessed     1,000      1,200
# 1      Macronutrients
# 2           Protein g                        RDA        13         19
# 3      Protein % kcal                       AMDR        20         30
# 4      Carbohydrate g                        RDA       130        130
#
#      Male 4-8 Female 9-13 Male 9-13 Female 14-18        Male 14-18  \
# 0  1400\n1600       1,600     1,800        1,800  2200\n2800\n3200
# 1
# 2          19          34        34           46                52
# 3          30          30        30           30                30
# 4         130         130       130          130               130
#
#   Female 19-30        Male 19-30 Female 31-50 Male 31-50 Female 51+ Male 51+
# 0        2,000  2400\n2600\n3000        1,800      2,200      1,600    2,000
# 1
# 2           46                56           46         56         46       56
# 3           35                35           35         35         35       35
# 4          130               130          130        130        130      130

# %%
user = "laialex@berkeley.edu"
apikey = {'laialex@berkeley.edu':"JHdQ6j02nQrZtnwaFLHinmHRPh3J8YAF7rZrzFMY"}

# %%
fdc.search(apikey[user],"crunchy peanut butter")
# Out:
#      fdcId            description dataType       gtinUpc publishedDate  \
# 0   521183  CRUNCHY PEANUT BUTTER  Branded  070980134019    2019-04-01
# 1   454839  CRUNCHY PEANUT BUTTER  Branded  015400454759    2019-04-01
# 2   512844  CRUNCHY PEANUT BUTTER  Branded  021110210110    2019-04-01
# 3   455474  CRUNCHY PEANUT BUTTER  Branded  041268196135    2019-04-01
# 4   455481  CRUNCHY PEANUT BUTTER  Branded  041268198146    2019-04-01
# 5   543056  CRUNCHY PEANUT BUTTER  Branded   04656700415    2019-04-01
# 6   775542  CRUNCHY PEANUT BUTTER  Branded  046567004174    2020-02-27
# 7   775520  CRUNCHY PEANUT BUTTER  Branded  046567016382    2020-02-27
# 8   572426  CRUNCHY PEANUT BUTTER  Branded  075450040463    2019-04-01
# 9   721392  CRUNCHY PEANUT BUTTER  Branded  085239041079    2019-12-06
# 10  780724  CRUNCHY PEANUT BUTTER  Branded  088252010121    2020-02-27
# 11  456909  CRUNCHY PEANUT BUTTER  Branded  710069016200    2019-04-01
# 12  535574  CRUNCHY PEANUT BUTTER  Branded  817974020039    2019-04-01
# 13  454532  CRUNCHY PEANUT BUTTER  Branded  011110714619    2019-04-01
# 14  386061  CRUNCHY PEANUT BUTTER  Branded  011110791665    2019-04-01
# 15  456036  CRUNCHY PEANUT BUTTER  Branded   07203671347    2019-04-01
# 16  456514  CRUNCHY PEANUT BUTTER  Branded  086854062593    2019-04-01
# 17  456606  CRUNCHY PEANUT BUTTER  Branded  092825111597    2019-04-01
# 18  388493  CRUNCHY PEANUT BUTTER  Branded  011225421884    2019-04-01
# 19  454864  CRUNCHY PEANUT BUTTER  Branded  015984660362    2019-04-01
# 20  518753  CRUNCHY PEANUT BUTTER  Branded  021110210219    2019-04-01
# 21  455201  CRUNCHY PEANUT BUTTER  Branded   03003409204    2019-04-01
# 22  359843  CRUNCHY PEANUT BUTTER  Branded  070690282031    2019-04-01
# 23  542915  CRUNCHY PEANUT BUTTER  Branded  041130286612    2019-04-01
# 24  455391  CRUNCHY PEANUT BUTTER  Branded  041130302107    2019-04-01
# 25  381015  CRUNCHY PEANUT BUTTER  Branded  041497121823    2019-04-01
# 26  499549  CRUNCHY PEANUT BUTTER  Branded  859459002024    2019-04-01
# 27  399770  CRUNCHY PEANUT BUTTER  Branded  011110016195    2019-04-01
# 28  475661  CRUNCHY PEANUT BUTTER  Branded  011110019073    2019-04-01
# 29  539172  CRUNCHY PEANUT BUTTER  Branded  029000016583    2019-04-01
# 30  639128  CRUNCHY PEANUT BUTTER  Branded   07203671349    2019-12-06
# 31  572733  CRUNCHY PEANUT BUTTER  Branded   07203676444    2019-04-01
# 32  563253  CRUNCHY PEANUT BUTTER  Branded  041270934428    2019-04-01
# 33  628262  CRUNCHY PEANUT BUTTER  Branded  041303031100    2019-12-06
# 34  388551  CRUNCHY PEANUT BUTTER  Branded  041318210651    2019-04-01
# 35  381170  CRUNCHY PEANUT BUTTER  Branded  041497121861    2019-04-01
# 36  584399  CRUNCHY PEANUT BUTTER  Branded  041497121960    2019-04-01
# 37  585861  CRUNCHY PEANUT BUTTER  Branded  041498143343    2019-04-01
# 38  455615  CRUNCHY PEANUT BUTTER  Branded  042187264981    2019-04-01
# 39  572402  CRUNCHY PEANUT BUTTER  Branded  075450040425    2019-04-01
# 40  532157  CRUNCHY PEANUT BUTTER  Branded  075450173598    2019-04-01
# 41  454626  CRUNCHY PEANUT BUTTER  Branded  011161032274    2019-04-01
# 42  400606  CRUNCHY PEANUT BUTTER  Branded  078742370026    2019-04-01
# 43  698822  CRUNCHY PEANUT BUTTER  Branded  081864000474    2019-12-06
# 44  456602  CRUNCHY PEANUT BUTTER  Branded  092825111566    2019-04-01
# 45  499708  CRUNCHY PEANUT BUTTER  Branded  851087000021    2019-04-01
# 46  773950  CRUNCHY PEANUT BUTTER  Branded  708820806832    2020-02-27
# 47  383273  CRUNCHY PEANUT BUTTER  Branded  725439941730    2019-04-01
# 48  525813  CRUNCHY PEANUT BUTTER  Branded  725439941969    2019-04-01
# 49  475834  CRUNCHY PEANUT BUTTER  Branded   01121303141    2019-04-01
#
#                         brandOwner  \
# 0      Central Grocers Co-Op, Inc.
# 1       Western Family Foods, Inc.
# 2          Marsh Supermarkets, LLC
# 3              Hannaford Bros. Co.
# 4              Hannaford Bros. Co.
# 5                          Raley's
# 6                          Raley's
# 7                          Raley's
# 8                     Hy-Vee, Inc.
# 9                    GOOD & GATHER
# 10             Algood Food Company
# 11       Cachere Distributing Inc.
# 12                       BRANDLESS
# 13                  The Kroger Co.
# 14                  The Kroger Co.
# 15              Harris-Teeter Inc.
# 16             Ingles Markets Inc.
# 17      Brookshire Grocery Company
# 18           Kingston Marketing Co
# 19                        REDNER'S
# 20         Marsh Supermarkets, LLC
# 21               Giant Eagle, Inc.
# 22  John B. Sanfilippo & Son, Inc.
# 23                 Supervalu, Inc.
# 24                 Supervalu, Inc.
# 25              Weis Markets, Inc.
# 26    Velvet Peanut Butter Company
# 27                  The Kroger Co.
# 28                  The Kroger Co.
# 29            Nabisco Food Company
# 30              Harris-Teeter Inc.
# 31              Harris-Teeter Inc.
# 32                       Iga, Inc.
# 33                 Supervalu, Inc.
# 34           Schnuck Markets, Inc.
# 35                    WEIS QUALITY
# 36                    WEIS QUALITY
# 37             Aldi-Benner Company
# 38      S. M. Flickinger Co., Inc.
# 39                    Hy-Vee, Inc.
# 40                    Hy-Vee, Inc.
# 41          Topco Associates, Inc.
# 42           Wal-Mart Stores, Inc.
# 43          Northampton Peanut Co.
# 44      Brookshire Grocery Company
# 45        Peanut Butter & Co, Inc.
# 46                    Meijer, Inc.
# 47          Delhaize America, Inc.
# 48          Delhaize America, Inc.
# 49                         SPARTAN
#
#                                           ingredients  \
# 0   SELECTED ROASTED PEANUTS, SUGAR, HYDROGENATED ...
# 1   PEANUTS, DEXTROSE, HYDROGENATED VEGETABLE OIL ...
# 2   PEANUTS, SUGAR, CONTAINS 2% OR LESS OF: FULLY ...
# 3   ROASTED PEANUTS, SUGAR CONTAINS 2% OR LESS OF:...
# 4   ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 5   PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
# 6   DRY ROASTED PEANUTS, SUGAR, HYDROGENATED VEGET...
# 7   DRY ROASTED PEANUTS, SUGAR, HYDROGENATED VEGET...
# 8   PEANUTS, SUGAR, HYDROGENATED VEGETABLE OILS (R...
# 9                        DRY ROASTED ORGANIC PEANUTS.
# 10  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 11  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OILS (C...
# 12                      ORGANIC PEANUTS AND SEA SALT.
# 13  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 14  ORGANIC PEANUTS, ORGANIC PALM OIL, ORGANIC CAN...
# 15  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 16  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL, (R...
# 17  SELECTED ROASTED PEANUTS, SUGAR, HYDROGENATED ...
# 18  PEANUTS, DEXTROSE, HYDROGENATED VEGETABLE OIL ...
# 19  SELECTED ROASTED PEANUTS, SUGARS, HYDROGENATED...
# 20  PEANUTS, SUGAR, CONTAINS 2% OR LESS OF: FULLY ...
# 21  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
# 22  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
# 23  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 24  PEANUTS, DEXTROSE, FULLY HYDROGENATED VEGETABL...
# 25  ROASTED PEANUTS, SUGAR, CONTAINS LESS THAN 2% ...
# 26  PEANUTS, SUGAR, FULLY HYDROGENATED VEGETABLE O...
# 27  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 28                             ROASTED PEANUTS, SALT.
# 29  INGREDIENTS: ROASTED PEANUTS, SUGAR, CONTAINS ...
# 30  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 31        DRY ROASTED BLANCHED ORGANIC PEANUTS, SALT.
# 32  SELECTED ROASTED PEANUTS, SUGAR, HYDROGENATED ...
# 33  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 34  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
# 35  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 36  ROASTED PEANUTS, SUGAR, CONTAINS 2% OR LESS OF...
# 37  DRY ROASTED PEANUTS, SUGAR, HYDROGENATED VEGET...
# 38  ROASTED PEANUTS, CORN SYRUP, HYDROGENATED RAPE...
# 39  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OILS (R...
# 40  ROASTED PEANUTS, SUGAR, HYDROGENATED VEGETABLE...
# 41  PEANUTS, SUGAR, CONTAINS 2% OR LESS OF: FULLY ...
# 42  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
# 43  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OILS (R...
# 44  SELECTED ROASTED PEANUTS, SUGAR, HYDROGENATED ...
# 45               PEANUTS, CANE SUGAR, PALM OIL, SALT.
# 46                               DRY ROASTED PEANUTS.
# 47             ORGANIC DRY ROASTED PEANUTS, SEA SALT.
# 48                         DRY ROASTED PEANUTS, SALT.
# 49  PEANUTS, SUGAR, HYDROGENATED VEGETABLE OIL (RA...
#
#                                    allHighlightFields      score
# 0   <b>Ingredients</b>: SELECTED ROASTED <em>PEANU...  855.72906
# 1   <b>Ingredients</b>: <em>PEANUTS</em>, DEXTROSE...  855.72906
# 2   <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, C...  855.72906
# 3   <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 4   <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 5   <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 6   <b>Ingredients</b>: DRY ROASTED <em>PEANUTS</e...  855.72906
# 7   <b>Ingredients</b>: DRY ROASTED <em>PEANUTS</e...  855.72906
# 8   <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 9   <b>Ingredients</b>: DRY ROASTED ORGANIC <em>PE...  855.72906
# 10  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 11  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 12  <b>Ingredients</b>: ORGANIC <em>PEANUTS</em> A...  855.72906
# 13  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 14  <b>Ingredients</b>: ORGANIC <em>PEANUTS</em>, ...  855.72906
# 15  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 16  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 17  <b>Ingredients</b>: SELECTED ROASTED <em>PEANU...  855.72906
# 18  <b>Ingredients</b>: <em>PEANUTS</em>, DEXTROSE...  855.72906
# 19  <b>Ingredients</b>: SELECTED ROASTED <em>PEANU...  855.72906
# 20  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, C...  855.72906
# 21  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 22  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 23  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 24  <b>Ingredients</b>: <em>PEANUTS</em>, DEXTROSE...  855.72906
# 25  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 26  <b>Brand Owner</b>: Velvet <em>Peanut</em> <em...  855.72906
# 27  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 28  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 29  <b>Ingredients</b>: INGREDIENTS: ROASTED <em>P...  855.72906
# 30  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 31  <b>Ingredients</b>: DRY ROASTED BLANCHED ORGAN...  855.72906
# 32  <b>Ingredients</b>: SELECTED ROASTED <em>PEANU...  855.72906
# 33  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 34  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 35  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 36  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 37  <b>Ingredients</b>: DRY ROASTED <em>PEANUTS</e...  855.72906
# 38  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 39  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 40  <b>Ingredients</b>: ROASTED <em>PEANUTS</em>, ...  855.72906
# 41  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, C...  855.72906
# 42  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906
# 43  <b>Brand Owner</b>: Northampton <em>Peanut</em...  855.72906
# 44  <b>Ingredients</b>: SELECTED ROASTED <em>PEANU...  855.72906
# 45  <b>Brand Owner</b>: <em>Peanut</em> <em>Butter...  855.72906
# 46  <b>Ingredients</b>: DRY ROASTED <em>PEANUTS</em>.  855.72906
# 47  <b>Ingredients</b>: ORGANIC DRY ROASTED <em>PE...  855.72906
# 48  <b>Ingredients</b>: DRY ROASTED <em>PEANUTS</e...  855.72906
# 49  <b>Ingredients</b>: <em>PEANUTS</em>, SUGAR, H...  855.72906

# %%
id = 454532
fdc.nutrients(apikey[user],fdc_id=id)
# Out:
#                                     Quantity Units
# Calcium, Ca                           62.000    mg
# Iron, Fe                               2.250    mg
# Vitamin A, IU                          0.000    IU
# Vitamin C, total ascorbic acid         0.000    mg
# Riboflavin                             0.106    mg
# Niacin                                12.500    mg
# Cholesterol                            0.000    mg
# Protein                               21.880     g
# Total lipid (fat)                     46.880     g
# Carbohydrate, by difference           28.120     g
# Energy                               562.000  kcal
# Sugars, total including NLEA          12.500     g
# Fiber, total dietary                   6.200     g
# Sodium, Na                           469.000    mg
# Fatty acids, total trans               0.000     g
# Fatty acids, total saturated           7.810     g
# Fatty acids, total monounsaturated    21.880     g
# Fatty acids, total polyunsaturated    14.060     g

# %%
# Some columns which ought to be numeric are actually str; convert them
#df_food_data['Price'] = df_food_data['Price'].astype(float)
#df_food_Data['Quantity'] = df_food_data['Quantity'].astype(float)
#df_food_Data['FDC'] = df_food_data['FDC'].astype(int)

# %%
D = {}
count = 0
list(df_food_data['Food'])
"""
for food in  df_food_data.Food.tolist():
    try:
        FDC = df_food_data.loc[df_food_data.Food==food,:].FDC[count]
        count+=1
        D[food] = fdc.nutrients(apikey[user],FDC).Quantity
    except AttributeError: 
        warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))        

D = pd.DataFrame(D,dtype=float)

D"""
# Out:
# '\nfor food in  df_food_data.Food.tolist():\n    try:\n        FDC = df_food_data.loc[df_food_data.Food==food,:].FDC[count]\n        count+=1\n        D[food] = fdc.nutrients(apikey[user],FDC).Quantity\n    except AttributeError: \n        warnings.warn("Couldn\'t find FDC Code %s for food %s." % (food,FDC))        \n\nD = pd.DataFrame(D,dtype=float)\n\nD'

# %%
# Try your own quantities and units.
# If units are missing try adding to ./Data/food_units.txt

print(fdc.units(5,'lbs'))
print(fdc.units(1,'gallon'))
print(fdc.units(2,'tea_bag'))
print(fdc.units(12,'donut'))
# Out:
# 22.679618500000004 hectogram
# 37.85411783999999 deciliter
# 0.06 hectogram
# nan milliliter

# %%
# Convert food quantities to FDC units
df_food_Data['FDC Quantity'] = df_food_data[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
df_food_data['FDC Price'] = df_food_data['Price']/df_food_data['FDC Quantity']

df_food_data.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
Prices = df_food_data.groupby('Food')['FDC Price'].min()

Prices.head()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-105-6f8871b39bb2>", line 2, in <module>
#     df_food_Data['FDC Quantity'] = df_food_data[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pandas\core\frame.py", line 6913, in apply
#     return op.get_result()
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pandas\core\apply.py", line 186, in get_result
#     return self.apply_standard()
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pandas\core\apply.py", line 292, in apply_standard
#     self.apply_series_generator()
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pandas\core\apply.py", line 321, in apply_series_generator
#     results[i] = self.f(v)
#
#   File "<ipython-input-105-6f8871b39bb2>", line 2, in <lambda>
#     df_food_Data['FDC Quantity'] = df_food_data[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#
#   File "C:\Users\laial\Berkeley\eep153\project2\fooddatacentral.py", line 64, in units
#     x = ureg.Quantity(float(q),u)
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\quantity.py", line 190, in __new__
#     inst._units = inst._REGISTRY.parse_units(units)._units
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\registry.py", line 1065, in parse_units
#     units = self._parse_units(input_string, as_delta)
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\registry.py", line 1264, in _parse_units
#     return super()._parse_units(input_string, as_delta)
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\registry.py", line 1086, in _parse_units
#     units = ParserHelper.from_string(input_string)
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\util.py", line 574, in from_string
#     ret = build_eval_tree(gen).evaluate(cls.eval_token)
#
#   File "C:\Users\laial\Anaconda3\lib\site-packages\pint\pint_eval.py", line 98, in evaluate
#     raise DefinitionSyntaxError('missing unary operator "%s"' % op_text)
#
#   File "<string>", line unknown
# DefinitionSyntaxError: missing unary operator "/"

# %%
# Choose sex/age group:
groups = ["Child 1-3", "Female 4-8", "Male 4-8", "Female 9-13", "Male 9-13", "Female 14-18", "Male 14-18", "Female 19-30", "Male 19-30", "Female 31-50", "Male 31-50", "Female 51+", "Male 51+"]
group = "Female 4-8"

# Define *minimums*
bmin = df_nutrition_min.set_index('Nutrition')[group]

# Define *maximums*
bmax = df_nutrition_max.set_index('Nutrition')[group]

# Inspect:
bmin.head()
# Out:
# Nutrition
# Source: Appendix 7    1,200
# Macronutrients
# Protein g                19
# Protein % kcal           10
# Carbohydrate g          130
# Name: Female 4-8, dtype: object

# %%
c = Prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = list(set(c.index.tolist()).intersection(D.columns.tolist()))
c = c[use]

c

# %%
# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[c.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Minimum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([Amin,-Amax])

A

# %%
b = pd.concat([bmin,-bmax]) # Note sign change for max constraints
# What does concat do???

b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-e53d13de461b> in <module>
# ----> 1 b = pd.concat([bmin,-bmax]) # Note sign change for max constraints
#       2
#       3 b
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __neg__(self)
#    1514             or is_object_dtype(values)
#    1515         ):
# -> 1516             arr = operator.neg(values)
#    1517         else:
#    1518             raise TypeError(
#
# TypeError: bad operand type for unary -: 'str'

# %%
from  scipy.optimize import linprog as lp
import numpy as np

tol = 1e-6 # Numbers in solution smaller than this (in absolute value) treated as zeros

# Now solve problem!  (Note that the linear program solver we'll use assumes
# "less-than-or-equal" constraints.  We can switch back and forth by
# multiplying $A$ and $b$ by $-1$.)

result = lp(c, -A, -b, method='interior-point')

result

# %%
print("Cost of diet for %s is $%4.2f per day." % (group,result.fun))

# %%
# Put back into nice series
diet = pd.Series(result.x,index=c.index)

print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.

# %%
tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b)})
print("\nWith the following nutritional outcomes of interest:")
tab

# %%
print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
